# %% [markdown]
# <img src="resources/physicsOtago.png" width="600">
#
# $$
# \def\julia{\texttt{julia}}
# \def\dashint{{\int\!\!\!\!\!\!-\,}}
# \def\infdashint{\dashint_{\!\!\!-\infty}^{\,\infty}}
# \def\D{\,{\rm d}}
# \def\E{{\rm e}}
# \def\dx{\D x}
# \def\dt{\D t}
# \def\dz{\D z}
# \def\C{{\mathbb C}}
# \def\R{{\mathbb R}}
# \def\CC{{\cal C}}
# \def\HH{{\cal H}}
# \def\I{{\rm i}}
# \def\Res_#1{\underset{#1}{\rm Res}}\,
# \def\sech{{\rm sech}\,}
# \def\vc#1{{\mathbf #1}}
# \def\qq{\qquad\qquad}
# \def\qfor{\qquad\hbox{for}\qquad}
# \def\qwhere{\qquad\hbox{where}\qquad}
# \def\ale#1{\begin{align}#1\end{align}}
# \def\em{\epsilon_m}
# \def\unit#1{{\rm #1}}
# $$
#
# # PHSI 365: Computational Physics <img align="right" src="resources/tmp.gif" width="400" height="400">
#
# University of Otago, 2019
#
# Dr. Ashton Bradley (Coordinator)
# <br>
# ashton.bradley@otago.ac.nz
# <br>
#
# _Image made with_ [Plots.jl](http://docs.juliaplots.org/latest/)

# %% [markdown]
# # Course information
# - Blackboard

# %% [markdown]
# ## Assessment
# - Lab assignments 50%.
#
# - Final Exam 50%. 2 hours, "open book" - you can use your files from the semester, but won't have access outside the lab computer file system during the exam.

# %% [markdown]
# ## Lectures and tutorials
#
# - Lectures: Tuesday 1pm, Thursday 11am (room 314).
#
# - Tutorial/Help Room: Tuesday 11am, Lab A (MA242).
# The tutorial/help room is for lab assignment help, but please also feel free to ask questions about physics, programming, and assignments.
#
# - Labs: Friday 2-5pm every weeek lecturer and demonstrators will be present in Lab A (MA242). _The room is booked until 6pm._
# You will **not** need a lab book:
# <div class="alert alert-block alert-info">
# All laboratory assignments will be written in Jupyter notebooks, and assessed in this format, as will the final exam.
# </div>

# %% [markdown]
# # What is this course about?
#
# <div class="alert alert-block alert-info">
# The Grand Challenge: explore and understand Nature in all its richness and complexity
# </div>
#
#
#
# Computers can help!
#
# <img src="attachment:interesting.png" width="400">

# %% [markdown]
# ## What you will learn in this course:
# - Computational and analytical skills for physics problem solving
#
# - Experience with applied mathematics and real-world problem solving
#
# - Specific skills: computer modelling; analytic and semi-analytic methods that give insight into complex systems.
#
# - Computing environment: **Julia**, state-of-the-art language ___designed specifically for computational science___.

# %% [markdown]
# ### Codequiz: What does this code do?

# %%
f(x) = x^2
# Out:
# f (generic function with 1 method)

# %%
f(3)
# Out:
# 9

# %%
f(3.0)
# Out:
# 9.0

# %% [markdown]
# __tl;dr:__ functions are objects that process inputs and generate outputs. Simple functions produce the ___same___ kind of data as their inputs.

# %% [markdown]
# ## Physics and Computation
#
# Despite concern that the end of [Moore's law](https://en.wikipedia.org/wiki/Moore%27s_law) may be nigh, computer technology has continued to advance at a rapid pace. We have also seen enormous change in what computers can be used to do even in the last 5 years.
#
# - 2017 AI (Machine Learning) system [Alpha Zero](https://en.wikipedia.org/wiki/AlphaZero) beat the previous best computer player after playing itself for only 24 hours, with no prior input.
# - [2017 the year that robots really, truly arrived](https://www.wired.com/story/2017-was-the-year-the-robots-really-truly-arrived/).
# - [Atlas](https://www.bostondynamics.com/atlas) from [Boston Dynamics](https://www.bostondynamics.com/) showing us how its done.
# - Struggle between [robot](https://www.youtube.com/watch?v=W1LWMk7JB80) and human.
#
#
# __Fun fact:__ The [perceptron](https://en.wikipedia.org/wiki/Perceptron) (birth of machine learning) was invented by the same person who invented a [method of detecting extra-solar planets](https://en.wikipedia.org/wiki/Methods_of_detecting_exoplanets) (who was it?)

# %% [markdown]
# Psychologist [Frank Rosenblatt](https://en.wikipedia.org/wiki/Frank_Rosenblatt#cite_note-13), working at the Cornell Auronautical Laboratory.

# %% [markdown]
# ## Physics
#
# In 2017 the Nobel Prize in Physics awarded just one year after LIGO's astonishing observations of [gravity waves emitted by two black holes merging](https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.116.061102).
#
# As physicists, we are curious problem solvers, and our basic trade is insight. Not just any kind of insight. We aim for a complete, rigorous, and quantitative understanding of the governing principles of nature - at least, that part of nature that can be understood mathematically.
#
# In addition to detailed observations of nature, our work is thus fundamentally mathematical, and oftentimes computational: a process of either generating mathematical models and their numerical predictions, or testing predictions against physical observations.
#
# - [What computational physics is really about](https://www.wired.com/2015/11/what-computational-physics-is-really-about/)
# - [You should be coding in your physics course](https://www.wired.com/2015/08/coding-physics-course/)
#
# ___Bottom line: model building and algorithmic thinking___

# %% [markdown]
# ## Gravitational waves (LIGO)
#
# In the culmination of decades of effort, when the modern LIGO apparatus was first switched on, data began pouring in, and soon the collaboration revealed signatures of gravity waves - ripples in space-time emitted in the violent merger of two black holes.
#
# <img src="resources/Wavy.gif" width="200">

# %% [markdown]
# [By NASA/JPL, Public Domain](https://commons.wikimedia.org/w/index.php?curid=186327)
#
# In an important development for the advancement of ___open science___, the analysis and simulation data for the [landmark paper](http://physics.aps.org/featured-article-pdf/10.1103/PhysRevLett.116.061102) was published as Jupyter notebooks:
#
# <img src="resources/1000px-LIGO_measurement_of_gravitational_waves.svg.png" width="600">
#
# [By B. P. Abbott et al. (LIGO Scientific Collaboration and Virgo Collaboration), CC BY 3.0](https://commons.wikimedia.org/w/index.php?curid=46987868)

# %% [markdown]
# ## The role of computation
# The power of modern computers has produced a kind of third way of doing science:
#
# Experiment $\longleftrightarrow$ Computation $\longleftrightarrow$ Theory
#
# <img src="resources/compPhys.png" width="300">
#
# [By Nicoguaro - Own work, CC0](https://commons.wikimedia.org/w/index.php?curid=47047458)

# %% [markdown]
# ## Insight
# Far from being automatic insight generators, computers are just simple number crunchers (notwithstanding recent advances in congnitive ability, deep neural networks such as AlphaGo).
#
# In order to do computational physics well, it is essential to
#
# - Have a solid understanding of the physics involved
#
#
# - Have a keen eye for debugging, "sanity checking" and
#
#
# - Take a sober, skeptical view of your results
#
# By debugged, sanity checking, and testing, we build confidence in the validity of our results, and their interpretation.

# %% [markdown]
# __Fun fact:__ Which pioneering scientist carried out the first computer experiments?

# %% [markdown]
# Studies of nonlinear dynamics in a chian of oscillators were carried out on the [MANIAC-1](https://en.wikipedia.org/wiki/MANIAC_I) (Los Alamos) in 1953 by [Mary Tsingou](https://en.wikipedia.org/wiki/Fermi%E2%80%93Pasta%E2%80%93Ulam%E2%80%93Tsingou_problem).

# %% [markdown]
# > "_I've realised I don't ___really___ understand a math/physics problem until I have written code to solve it_"
# (any fourth year student)
#
# <div class="alert alert-block alert-info">
# It is important to realise that generic approaches such as machine learning are only of limited value without real insight as to the nature of the problem being solved. Often this insight comes from Physics.
# </div>
#
# [The cart-pole problem is a classic example](https://fluxml.ai/experiments/cartPole/) where input from the equations of motion and efficient julia code can allow the for rapid training, whereas without any knowledge of the problem, or with a poor implementation, the Neural Network takes much(!) longer to train.
#
# ![cart_pole.png](attachment:cart_pole.png)

# %% [markdown]
# # What is Julia?
# - Modern language for technical computing
#
# - Solves the two-language problem.
#
# - ___Fast:___ [Benchmarks](https://julialang.org/benchmarks/)
#
# > _"Julia is the fastest modern open-source language for data science, machine learning and scientific computing. Julia provides the functionality, ease-of-use and intuitive syntax of R, Python, Matlab, SAS or Stata combined with the speed, capacity and performance of C, C++ or Java."_
#
# - ___High level:___
#
# - [Why we created julia](https://julialang.org/blog/2012/02/why-we-created-julia/)
#
# > _"We want a language that’s open source, with a liberal license. We want the speed of C with the dynamism of Ruby. We want a language that’s homoiconic, with true macros like Lisp, but with obvious, familiar mathematical notation like Matlab. We want something as usable for general programming as Python, as easy for statistics as R, as natural for string processing as Perl, as powerful for linear algebra as Matlab, as good at glueing programs together as the shell. Something that is dirt simple to learn, yet keeps the most serious hackers happy. We want it interactive and we want it compiled.
# (Did we mention it should be as fast as C?)"_

# %% [markdown]
# ## Watch your language ...
#
# - [Julia](https://julialang.org/): State of the art language designed specifically for **technical computing**
# - Designed specifically to overcome limitations of Matlab, Python, to reach the speed of C in a scripting language.
# - A hybrid of:
#     - *R, Python, Matlab, C, Fortran, Ruby, Lisp, Fortress...*
# - Conceived at MIT, born on Github.
# - **Open Source**: written by scientists for scientists.
# - Julia programeers are now in high demand in all tech sectors: **industry, academia, government, and voluntary.**
# - Official language site [Julialang.org](https://julialang.org)
# - [Julia on github](https://github.com/JuliaLang/julia)
# - [Julia computing](https://juliacomputing.com)

# %% [markdown]
# ## Julia Resources
#
# There are many excellent resources on the web.
#
# A few places to start:
#
# - [Documentation browser](https://pkg.julialang.org/docs/) that collects all documentation for registered julia packages.
# - [Julia cheat sheet](http://math.mit.edu/~stevenj/Julia-cheatsheet.pdf) for some connections with other highl level languages.
# - [Julia bloggers](https://julialang.org/blog/) to see what julia users and developers are up to.
# - [Stochastic Lifestyle](http://www.stochasticlifestyle.com) a nice resource for technical julia questions.
# - [Learning](https://julialang.org/learning/)
# - [Teaching](https://julialang.org/teaching/)

# %% [markdown]
# ## Interesting developments
# - New developments in ML: [Differentiable control problems](https://fluxml.ai/2019/03/05/dp-vs-rl.html) leveraging Physics!
# - [Petaflop club](https://juliacomputing.com/communication/2017/09/12/julia-joins-petaflop-club.html) - Julia has joined the rarefied ranks of computing languages that have achieved peak performance exceeding one petaflop per second – the so-called ‘Petaflop Club.’

# %% [markdown]
# ## Jupyter
#
# <div class="alert alert-block alert-info">
# code+markdown+LaTeX in a universal notebook format
# </div>
#
# - You are looking at it! (actually jupyter-lab)
#
#
# - __Ju-Py-teR (Julia, Python, R)__ notebook environment
#
#
# - Future of __open science__, see the original [LIGO paper](https://doi.org/10.1103/PhysRevLett.116.061102), and the [ipython notebook](https://losc.ligo.org/s/events/GW150914/GW150914_tutorial.html) walking readers through the analysis.
#
#
# - Useful resource for writing text in jupyter: [Markdown cheatsheet](http://datascience.ibm.com/blog/markdown-for-jupyter-notebooks-cheatsheet/)
#
#
# - The combination of Julia and Jupyter will make our task a lot easier.

# %% [markdown]
# # Julia 101
# One our our central tasks is to get comfortable in a new language.

# %% [markdown]
# ## Julia package manager
#
# [Game changing packages](https://juliacomputing.com/game-changing-packages/)
#
# Before we even get to talking about computational modelling in Julia, let's get familiar with using Julia's package manager `Pkg`.
# - Provides easy way to install and use code.
#
#
# - Free and easy code sharing and extending.
#
#
# - Built on **git**, and built into the fundamental structure of Julia

# %% [markdown]
# ## Main commands

# %% [markdown]
# ## Install and use a package
# To add IJulia, the jupyter notebook environment for julia:
#
# `]add IJulia`
#
# To load the package:
#
# `using IJulia`

# %% [markdown]
# ## Launching Jupyter
# Once IJulia is installed, to open a `Jupyter` notebook (the main `julia` interface in this course) execute the julia commands
# ```julia
# using IJulia
# notebook()
# ```
# and you will see a browser open a window identical to this one you are reading.

# %% [markdown]
# ## Packages used in this course
# Let's add most of what we need for PHSI365. In the jupyter notebook environment, we use a special `Pkg` syntax to invoke commands from the package manager environment directly as a julia command:

# %%
using Pkg
pkg"add Plots OrdinaryDiffEq QuadGK FFTW LinearAlgebra Statistics"
pkg"add Interact LaTeXStrings ParameterizedFunctions SparseArrays Printf"
pkg"add Juno Atom"
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [37e2e46d] + LinearAlgebra
#   [10745b16] + Statistics
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [de0858da] + Printf
#   [2f01184e] + SparseArrays
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]

# %% [markdown]
# ## Explore
# One of the great things about julia is its energetic and productive community. This is reflected in rapid state of the art package development that you can readily build up on your own scientific work. Yay open science!
#
# Julia files have the extension `.jl`, and package names also have this extension by convention.
#
# They can easily easily be found using google to search, e.g. `IJulia.jl`. There are a lot of very interesting packages; we will use a small subset in this course.
#
# A package aggregator can be found at
#
# [Julia Observer](https://juliaobserver.com/)
#
# Some suggestions for packages to explore:

# %% [markdown]
# ## Physics
# - [DynamicalSystems](https://github.com/JuliaDynamics/DynamicalSystems.jl)
# - [QuantumOptics](https://github.com/qojulia/QuantumOptics.jl)
# - [DifferentialEquations](https://github.com/JuliaDiffEq/DifferentialEquations.jl)
# - [Distributions](https://github.com/JuliaStats/Distributions.jl)
#
# ## Computation/Math
# - [QuadGK](https://github.com/JuliaMath/QuadGK.jl)
# - [GSL](https://github.com/JuliaMath/GSL.jl)
# - [SpecialFunctions](https://github.com/JuliaMath/SpecialFunctions.jl)
# - [FastTransforms](https://github.com/MikaelSlevinsky/FastTransforms.jl)
# - [FFTW](https://github.com/JuliaMath/FFTW.jl)
# - [FastGaussQuadrature](https://github.com/ajt60gaibb/FastGaussQuadrature.jl)
# - [Jump](https://github.com/JuliaOpt/JuMP.jl)
# - [SymPy](https://github.com/JuliaPy/SymPy.jl)
# - [ApproxFun](https://github.com/JuliaApproximation/ApproxFun.jl)

# %% [markdown]
# ### Machine Learning
# - [Flux](https://github.com/FluxML/Flux.jl)
# - [Knet](https://github.com/denizyuret/Knet.jl)
#
# ### Plotting
# - [PGFPlots](https://github.com/JuliaTeX/PGFPlots.jl)
# - [Makie](https://github.com/JuliaPlots/Makie.jl)
#
# ### Productivity
# - [Revise](https://github.com/timholy/Revise.jl)
# - [Parameters](https://github.com/mauro3/Parameters.jl)

# %% [markdown]
# ## How to read and test a package
#
# I want to emphasize that while the open-source world may look a little disorganized, don't be fooled: GitHub style code development is the leading industry standard, and leads to very reliable processes for development, testing and bugfixing.
#
# This brings me to my point:
#
# - all development is ___test-driven___, which means that there should be an extensive set of tests that pacakge code is subjected to before any updates go live. You can always test a package to see if it is passing its own tests.
#
#
# - Furthermore, if documentation is a bit light, you can read the test code to get some understanding of what the code is supposed to do.
#
#
# - You can also always read the source code since it is freely available. This is much easier than you might think: yay julia!
#
# Let's try an example. We are going to install a nonregistered package, and then run its tests.
#
# If all went well, the tests passed and we should have confidence using the package.

# %% [markdown]
# __tl;dr: Test driven development underpins open source stability.__
